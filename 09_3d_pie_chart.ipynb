# %%
import matplotlib.pyplot as plt

# %%
labels = ["Sachin", "Sehwag", "Kohli", "Yuvraj"]
runs = [15000, 8000, 12000, 9500]

# %%
explode=[0,0,0.1,0]
plt.title("Career Runs of Indian Batsmen")
plt.pie(runs, labels=labels,explode=explode,shadow=True,startangle=85)
plt.show()
